# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreyaM5/Experiment-11/blob/main/OST_experiment_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EXPERIMENT 11 : RESEARCH PROJECT WORKFLOW INTEGRATION

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
df = pd.read_csv('data.csv')

# Show data
print(df)

# Average marks
df['Average'] = df[['Maths','Science','English']].mean(axis=1)
print(df)

# Plot graph
df.plot(x='Name', y=['Maths','Science','English'], kind='bar')

plt.show()
# Out:
#     Name  Maths  Science  English
# 0   Aman     80       75       85
# 1   Riya     90       88       92
# 2  Rahul     70       65       72
# 3   Neha     85       80       78
#     Name  Maths  Science  English  Average
# 0   Aman     80       75       85     80.0
# 1   Riya     90       88       92     90.0
# 2  Rahul     70       65       72     69.0
# 3   Neha     85       80       78     81.0
